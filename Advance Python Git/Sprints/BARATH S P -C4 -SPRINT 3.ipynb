# %%
# Read the file
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
Data=pd.read_csv("DS1_C4_S3_SalesData_Practice.csv")
Data
# Out:
#    Month Store  Sales       State
# 0    Jan     A  21080      Alaska
# 1    Jan     B  32985       Texas
# 2    Jan     C  22369  California
# 3    Jan     D  45710     Montana
# 4    Jan     E  27113  New Mexico
# 5    Feb     A  27573      Alaska
# 6    Feb     B  31244       Texas
# 7    Feb     C  48624  California
# 8    Feb     D  31768     Montana
# 9    Feb     E  23851  New Mexico
# 10   Mar     A  33274      Alaska
# 11   Mar     B  27215       Texas
# 12   Mar     C  23475  California
# 13   Mar     D  21357     Montana
# 14   Mar     E  22130  New Mexico
# 15   Apr     A  26073      Alaska
# 16   Apr     B  45919       Texas
# 17   Apr     C  30279  California
# 18   Apr     D  21394     Montana
# 19   Apr     E  25184  New Mexico
# 20   May     A  37649      Alaska
# 21   May     B  44597       Texas
# 22   May     C  29697  California
# 23   May     D  28943     Montana
# 24   May     E  22541  New Mexico
# 25   Jun     A  28500      Alaska
# ...

# %%
# Task 1
Data.sort_values(["Sales"],ascending=True)
# Out:
#    Month Store  Sales       State
# 0    Jan     A  21080      Alaska
# 13   Mar     D  21357     Montana
# 18   Apr     D  21394     Montana
# 14   Mar     E  22130  New Mexico
# 2    Jan     C  22369  California
# 24   May     E  22541  New Mexico
# 12   Mar     C  23475  California
# 9    Feb     E  23851  New Mexico
# 19   Apr     E  25184  New Mexico
# 15   Apr     A  26073      Alaska
# 4    Jan     E  27113  New Mexico
# 11   Mar     B  27215       Texas
# 5    Feb     A  27573      Alaska
# 25   Jun     A  28500      Alaska
# 23   May     D  28943     Montana
# 22   May     C  29697  California
# 27   Jun     C  30200  California
# 17   Apr     C  30279  California
# 6    Feb     B  31244       Texas
# 8    Feb     D  31768     Montana
# 26   Jun     B  32896       Texas
# 1    Jan     B  32985       Texas
# 10   Mar     A  33274      Alaska
# 28   Jun     D  37098     Montana
# 20   May     A  37649      Alaska
# 29   Jun     E  41098  New Mexico
# ...

# %%
# Task 2
Data[Data.Sales>=45000]
# Out:
#    Month Store  Sales       State
# 3    Jan     D  45710     Montana
# 7    Feb     C  48624  California
# 16   Apr     B  45919       Texas

# %%
# Task 3
A=Data[Data.State=='California']
A
# Out:
#    Month Store  Sales       State
# 2    Jan     C  22369  California
# 7    Feb     C  48624  California
# 12   Mar     C  23475  California
# 17   Apr     C  30279  California
# 22   May     C  29697  California
# 27   Jun     C  30200  California

# %%
B=Data[Data.State=="Montana"]
B
# Out:
#    Month Store  Sales    State
# 3    Jan     D  45710  Montana
# 8    Feb     D  31768  Montana
# 13   Mar     D  21357  Montana
# 18   Apr     D  21394  Montana
# 23   May     D  28943  Montana
# 28   Jun     D  37098  Montana

# %%
C=Data[Data.State=='Texas']
C
# Out:
#    Month Store  Sales  State
# 1    Jan     B  32985  Texas
# 6    Feb     B  31244  Texas
# 11   Mar     B  27215  Texas
# 16   Apr     B  45919  Texas
# 21   May     B  44597  Texas
# 26   Jun     B  32896  Texas

# %%
sort_for_california=A.sort_values('Sales')
sort_for_california
# Out:
#    Month Store  Sales       State
# 2    Jan     C  22369  California
# 12   Mar     C  23475  California
# 22   May     C  29697  California
# 27   Jun     C  30200  California
# 17   Apr     C  30279  California
# 7    Feb     C  48624  California

# %%
sort_for_montana=B.sort_values('Sales')
sort_for_montana
# Out:
#    Month Store  Sales    State
# 13   Mar     D  21357  Montana
# 18   Apr     D  21394  Montana
# 23   May     D  28943  Montana
# 8    Feb     D  31768  Montana
# 28   Jun     D  37098  Montana
# 3    Jan     D  45710  Montana

# %%
sort_for_Texas=C.sort_values(['Sales'],ascending=True)
sort_for_Texas
# Out:
#    Month Store  Sales  State
# 11   Mar     B  27215  Texas
# 6    Feb     B  31244  Texas
# 26   Jun     B  32896  Texas
# 1    Jan     B  32985  Texas
# 21   May     B  44597  Texas
# 16   Apr     B  45919  Texas

# %%
# Task 4
Total_sales_for_california=A['Sales'].sum()
print("Total sales for California is:",Total_sales_for_california)
Total_sales_for_Texas=C['Sales'].sum()
print("Total sales for Sales:",Total_sales_for_Texas)
Total_sales_for_Montana=B['Sales'].sum()
print("Total sales for Montana is:",Total_sales_for_Montana)
# Out:
# Total sales for California is: 184644
# Total sales for Sales: 214856
# Total sales for Montana is: 186270

# %%
# Task 5
highest=A.sort_values('Sales',ascending=False)
highest
a=highest.iloc[[0],[1,2]]
a
# Out:
#   Store  Sales
# 7     C  48624

# %%
lowest=A.sort_values('Sales',ascending=True)
lowest
b=lowest.iloc[[0],[1,2]]
b
# Out:
#   Store  Sales
# 2     C  22369

# %%
# Task 6
Data
# Out:
#    Month Store  Sales       State
# 0    Jan     A  21080      Alaska
# 1    Jan     B  32985       Texas
# 2    Jan     C  22369  California
# 3    Jan     D  45710     Montana
# 4    Jan     E  27113  New Mexico
# 5    Feb     A  27573      Alaska
# 6    Feb     B  31244       Texas
# 7    Feb     C  48624  California
# 8    Feb     D  31768     Montana
# 9    Feb     E  23851  New Mexico
# 10   Mar     A  33274      Alaska
# 11   Mar     B  27215       Texas
# 12   Mar     C  23475  California
# 13   Mar     D  21357     Montana
# 14   Mar     E  22130  New Mexico
# 15   Apr     A  26073      Alaska
# 16   Apr     B  45919       Texas
# 17   Apr     C  30279  California
# 18   Apr     D  21394     Montana
# 19   Apr     E  25184  New Mexico
# 20   May     A  37649      Alaska
# 21   May     B  44597       Texas
# 22   May     C  29697  California
# 23   May     D  28943     Montana
# 24   May     E  22541  New Mexico
# 25   Jun     A  28500      Alaska
# ...

# %%
# Task 6
dict={'state':['Alaska','Texas','California','Montana','New Mexico'],'Sale in thousands':[174149,214856,184644,186270,161917]}
dict
# Out:
# {'state': ['Alaska', 'Texas', 'California', 'Montana', 'New Mexico'],
#  'Sale in thousands': [174149, 214856, 184644, 186270, 161917]}

# %%
new_df=pd.DataFrame(dict)
new_df
# Out:
#         state  Sale in thousands
# 0      Alaska             174149
# 1       Texas             214856
# 2  California             184644
# 3     Montana             186270
# 4  New Mexico             161917

# %%
# Task 7
total_sales=new_df.sort_values('Sale in thousands')
total_sales
total_sales.to_csv('total_sales.csv',index=False)

# %%
total_sales
# Out:
#         state  Sale in thousands
# 4  New Mexico             161917
# 0      Alaska             174149
# 2  California             184644
# 3     Montana             186270
# 1       Texas             214856
