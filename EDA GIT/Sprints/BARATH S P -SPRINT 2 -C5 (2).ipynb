# %%
import matplotlib as mat
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tabulate import tabulate
import seaborn as sns

# %%
# to read the file
df=pd.read_csv("DS1_C5_S2_EmployeeAttrition_Data_Practice.csv")
df
# Out:
#        Age Attrition     BusinessTravel              Department  \
# 0     41.0       Yes      Travel_Rarely                   Sales
# 1     49.0        No  Travel_Frequently  Research & Development
# 2     37.0       Yes      Travel_Rarely  Research & Development
# 3     33.0        No  Travel_Frequently  Research & Development
# 4     27.0        No      Travel_Rarely  Research & Development
# ...    ...       ...                ...                     ...
# 1465  36.0        No                NaN  Research & Development
# 1466  39.0        No      Travel_Rarely  Research & Development
# 1467  27.0        No      Travel_Rarely  Research & Development
# 1468  49.0        No  Travel_Frequently                   Sales
# 1469  34.0        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome EducationField  EmployeeNumber  \
# 0                    1  Life Sciences               1
# 1                    8  Life Sciences               2
# ...

# %%
df.shape
# Out:
# (1470, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1446 non-null   float64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1440 non-null   object
#  3   Department                1466 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   EducationField            1458 non-null   object
#  6   EmployeeNumber            1470 non-null   int64
#  7   EnvironmentSatisfaction   1470 non-null   int64
#  8   Gender                    1425 non-null   object
#  9   HourlyRate                1470 non-null   int64
#  10  JobInvolvement            1470 non-null   int64
#  11  JobRole                   1460 non-null   object
#  12  JobSatisfaction           1470 non-null   int64
# ...

# %%
df.head(5)
# Out:
#     Age Attrition     BusinessTravel              Department  \
# 0  41.0       Yes      Travel_Rarely                   Sales
# 1  49.0        No  Travel_Frequently  Research & Development
# 2  37.0       Yes      Travel_Rarely  Research & Development
# 3  33.0        No  Travel_Frequently  Research & Development
# 4  27.0        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# 0                 1  Life Sciences               1                        2
# 1                 8  Life Sciences               2                        3
# 2                 2          Other               4                        4
# 3                 3  Life Sciences               5                        4
# 4                 2        Medical               7                        1
#
#    Gender  HourlyRate  ...  OverTime PerformanceRating  \
# 0  Female          94  ...       Yes                 3
# ...

# %%
df.tail(5)
# Out:
#        Age Attrition     BusinessTravel              Department  \
# 1465  36.0        No                NaN  Research & Development
# 1466  39.0        No      Travel_Rarely  Research & Development
# 1467  27.0        No      Travel_Rarely  Research & Development
# 1468  49.0        No  Travel_Frequently                   Sales
# 1469  34.0        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome EducationField  EmployeeNumber  \
# 1465                23        Medical            2061
# 1466                 6        Medical            2062
# 1467                 4  Life Sciences            2064
# 1468                 2        Medical            2065
# 1469                 8        Medical            2068
#
#       EnvironmentSatisfaction Gender  HourlyRate  ...  OverTime  \
# 1465                        3   Male          41  ...        No
# 1466                        4   Male          42  ...        No
# ...

# %%
df.isnull().sum()
# Out:
# Age                         24
# Attrition                    0
# BusinessTravel              30
# Department                   4
# DistanceFromHome             0
# EducationField              12
# EmployeeNumber               0
# EnvironmentSatisfaction      0
# Gender                      45
# HourlyRate                   0
# JobInvolvement               0
# JobRole                     10
# JobSatisfaction              0
# MaritalStatus               56
# MonthlyIncome                0
# NumCompaniesWorked           0
# Over18                      54
# OverTime                     0
# PerformanceRating            0
# RelationshipSatisfaction     0
# TotalWorkingYears            0
# TrainingTimesLastYear        0
# WorkLifeBalance              0
# YearsAtCompany               0
# YearsInCurrentRole           0
# YearsSinceLastPromotion      0
# YearsWithCurrManager         0
# dtype: int64

# %%
Numcol=df.select_dtypes(exclude="object")
Numcol
# Out:
#        Age  DistanceFromHome  EmployeeNumber  EnvironmentSatisfaction  \
# 0     41.0                 1               1                        2
# 1     49.0                 8               2                        3
# 2     37.0                 2               4                        4
# 3     33.0                 3               5                        4
# 4     27.0                 2               7                        1
# ...    ...               ...             ...                      ...
# 1465  36.0                23            2061                        3
# 1466  39.0                 6            2062                        4
# 1467  27.0                 4            2064                        2
# 1468  49.0                 2            2065                        4
# 1469  34.0                 8            2068                        2
#
#       HourlyRate  JobInvolvement  JobSatisfaction  MonthlyIncome  \
# ...

# %%
Catcol=df.select_dtypes(include='object')
Catcol
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No                NaN  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %%
print(tabulate({"Numerical":Numcol,"Categorical":Catcol},headers=["Numerical","Categorical"]))
# Out:
# Numerical                 Categorical
# ------------------------  --------------
# Age                       Attrition
# DistanceFromHome          BusinessTravel
# EmployeeNumber            Department
# EnvironmentSatisfaction   EducationField
# HourlyRate                Gender
# JobInvolvement            JobRole
# JobSatisfaction           MaritalStatus
# MonthlyIncome             Over18
# NumCompaniesWorked        OverTime
# PerformanceRating
# RelationshipSatisfaction
# TotalWorkingYears
# TrainingTimesLastYear
# WorkLifeBalance
# YearsAtCompany
# YearsInCurrentRole
# YearsSinceLastPromotion
# YearsWithCurrManager

# %%
N_list=list(Numcol)
N_list
# Out:
# ['Age',
#  'DistanceFromHome',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'NumCompaniesWorked',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
C_list=list(Catcol)
C_list
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'Over18',
#  'OverTime']

# %%
def info_of_cat_and_num(col):
        print(f"The unique values in the {col} is:{df[col].nunique()}")
        print(f"The mode values in the {col} is:{df[col].mode()[0]}")
        print(f"The null values in the{col} is {df[col].isnull().sum()}")
        print("---------------------------------------------------------------------")

# %%
for i in N_list:
    info_of_cat_and_num(i)
# Out:
# The unique values in the Age is:43
# The mode values in the Age is:34.0
# The null values in theAge is 24
# ---------------------------------------------------------------------
# The unique values in the DistanceFromHome is:29
# The mode values in the DistanceFromHome is:2
# The null values in theDistanceFromHome is 0
# ---------------------------------------------------------------------
# The unique values in the EmployeeNumber is:1470
# The mode values in the EmployeeNumber is:1
# The null values in theEmployeeNumber is 0
# ---------------------------------------------------------------------
# The unique values in the EnvironmentSatisfaction is:4
# The mode values in the EnvironmentSatisfaction is:3
# The null values in theEnvironmentSatisfaction is 0
# ---------------------------------------------------------------------
# The unique values in the HourlyRate is:71
# The mode values in the HourlyRate is:66
# The null values in theHourlyRate is 0
# ...

# %%
for i in C_list:
    info_of_cat_and_num(i)
# Out:
# The unique values in the Attrition is:2
# The mode values in the Attrition is:No
# The null values in theAttrition is 0
# ---------------------------------------------------------------------
# The unique values in the BusinessTravel is:3
# The mode values in the BusinessTravel is:Travel_Rarely
# The null values in theBusinessTravel is 30
# ---------------------------------------------------------------------
# The unique values in the Department is:3
# The mode values in the Department is:Research & Development
# The null values in theDepartment is 4
# ---------------------------------------------------------------------
# The unique values in the EducationField is:6
# The mode values in the EducationField is:Life Sciences
# The null values in theEducationField is 12
# ---------------------------------------------------------------------
# The unique values in the Gender is:2
# The mode values in the Gender is:Male
# The null values in theGender is 45
# ...

# %%
df["Age"]=df["Age"].fillna(df["Age"].mean())
df["BusinessTravel"]=df["BusinessTravel"].fillna(df["BusinessTravel"].mode()[0])
df["Department"]=df["Department"].fillna(df["Department"].mode()[0])
df["EducationField"]=df["EducationField"].fillna(df["EducationField"].mode()[0])
df["Gender"]=df["Gender"].fillna(df["Gender"].mode()[0])
df["JobRole"]=df["JobRole"].fillna(df["JobRole"].mode()[0])
df["MaritalStatus"]=df["MaritalStatus"].fillna(df["MaritalStatus"].mode()[0])
df["Over18"]=df["Over18"].fillna(df["Over18"].mode()[0])

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# EducationField              0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PerformanceRating           0
# RelationshipSatisfaction    0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
# Task 1(i)
figsize,ax=plt.subplots(1,figsize=(15,7))
sns.countplot(x=df["BusinessTravel"],hue=df["Attrition"],ax=ax)
# Out:
# <Axes: xlabel='BusinessTravel', ylabel='count'>

# %%
# Task i(ii)
fig,ax=plt.subplots(1,figsize=(15,7))
sns.countplot(x=df["EducationField"],hue=df["Attrition"],data=df,ax=ax)
# Out:
# <Axes: xlabel='EducationField', ylabel='count'>

# %%
# Task i(iii)
fig,ax=plt.subplots(1,figsize=(15,7))
sns.countplot(x=df["Department"],hue=df["Attrition"],data=df,ax=ax)
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
# Task i(iv)
fig,ax=plt.subplots(1,figsize=(15,7))
sns.countplot(x=df["EnvironmentSatisfaction"],hue=df["Attrition"],data=df,ax=ax)
# Out:
# <Axes: xlabel='EnvironmentSatisfaction', ylabel='count'>

# %%
# Task i(v)
fig,ax=plt.subplots(1,figsize=(15,7))
sns.countplot(x="Gender",hue="Attrition",data=df,ax=ax)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# Task i(vi)
fig,ax=plt.subplots(1,figsize=(10,7))
sns.countplot(x=df["MaritalStatus"],hue=df["Attrition"],data=df,ax=ax)
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %%
# Task i(vii) 
fig,ax=plt.subplots(1,figsize=(15,7))
percentage=df["OverTime"].value_counts()
lables=list(df["Attrition"].value_counts().index)
plt.pie(percentage,labels=lables,autopct="%.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1b5b2a89d30>,
# ...
#  [Text(-0.6931655117563703, 0.8541203506014416, 'No'),
#   Text(0.6931655117563698, -0.854120350601442, 'Yes')],
#  [Text(-0.3780902791398383, 0.4658838276007863, '71.70%'),
#   Text(0.378090279139838, -0.4658838276007865, '28.30%')])

# %%
# Task i(viii)
fig,ax=plt.subplots(1,figsize=(15,7))
sns.countplot(x=df["PerformanceRating"],hue=df["Attrition"],data=df,ax=ax)
# Out:
# <Axes: xlabel='PerformanceRating', ylabel='count'>

# %%
# Task i(ix)
fig,ax=plt.subplots(1,figsize=(15,7))
sns.countplot(x=df["JobSatisfaction"],hue=df["Attrition"],data=df,ax=ax)
# Out:
# <Axes: xlabel='JobSatisfaction', ylabel='count'>

# %%
# Task 2(i)
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("Histogram")
ax[1].set_title("Boxplot")
sns.histplot(x=df["Age"],hue=df["Attrition"],data=df,ax=ax[0])
sns.boxplot(y=df["Age"],hue=df["Attrition"],data=df,ax=ax[1])
# Out:
# <Axes: title={'center': 'Boxplot'}, ylabel='Age'>

# %%
# Task 2(ii)
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("Histogram")
ax[1].set_title("Boxplot")
sns.histplot(x=df["HourlyRate"],hue=df["Attrition"],data=df,ax=ax[0])
sns.boxplot(y=df["HourlyRate"],hue=df["Attrition"],data=df,ax=ax[1])
# Out:
# <Axes: title={'center': 'Boxplot'}, ylabel='HourlyRate'>

# %%
# Task 2(iii)
# Task 2(i)
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("Histogram")
ax[1].set_title("Boxplot")
sns.histplot(x=df["MonthlyIncome"],hue=df["Attrition"],data=df,ax=ax[0])
sns.boxplot(y=df["MonthlyIncome"],hue=df["Attrition"],data=df,ax=ax[1])
# Out:
# <Axes: title={'center': 'Boxplot'}, ylabel='MonthlyIncome'>

# %%
# Task 2(iv)
# Task 2(i)
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("Histogram")
ax[1].set_title("Boxplot")
sns.histplot(x=df["DistanceFromHome"],hue=df["Attrition"],data=df,ax=ax[0])
sns.boxplot(y=df["DistanceFromHome"],hue=df["Attrition"],data=df,ax=ax[1])
# Out:
# <Axes: title={'center': 'Boxplot'}, ylabel='DistanceFromHome'>

# %%
# Task 2(v)
# Task 2(i)
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("Histogram")
ax[1].set_title("Boxplot")
sns.histplot(x=df["TotalWorkingYears"],hue=df["Attrition"],data=df,ax=ax[0])
sns.boxplot(y=df["TotalWorkingYears"],hue=df["Attrition"],data=df,ax=ax[1])
# Out:
# <Axes: title={'center': 'Boxplot'}, ylabel='TotalWorkingYears'>

# %%
# Task 3
Business_Travel=df[df["BusinessTravel"]=="Travel_Rarely"]
Business_Travel
# Out:
#        Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 0     41.0       Yes  Travel_Rarely                   Sales                 1
# 2     37.0       Yes  Travel_Rarely  Research & Development                 2
# 4     27.0        No  Travel_Rarely  Research & Development                 2
# 6     59.0        No  Travel_Rarely  Research & Development                 3
# 7     30.0        No  Travel_Rarely  Research & Development                24
# ...    ...       ...            ...                     ...               ...
# 1464  26.0        No  Travel_Rarely                   Sales                 5
# 1465  36.0        No  Travel_Rarely  Research & Development                23
# 1466  39.0        No  Travel_Rarely  Research & Development                 6
# 1467  27.0        No  Travel_Rarely  Research & Development                 4
# 1469  34.0        No  Travel_Rarely  Research & Development                 8
#
# ...

# %%
fig,ax=plt.subplots(1,figsize=(20,7))
sns.countplot(y=Business_Travel["JobRole"],hue=Business_Travel["Attrition"],data=Business_Travel,ax=ax)
# Out:
# <Axes: xlabel='count', ylabel='JobRole'>

# %%
# Task 4
Life_science=df[(df["EducationField"]=="Life Sciences")|(df["EducationField"]=="Medical")]
Life_science
# Out:
#        Age Attrition     BusinessTravel              Department  \
# 0     41.0       Yes      Travel_Rarely                   Sales
# 1     49.0        No  Travel_Frequently  Research & Development
# 3     33.0        No  Travel_Frequently  Research & Development
# 4     27.0        No      Travel_Rarely  Research & Development
# 5     32.0        No  Travel_Frequently  Research & Development
# ...    ...       ...                ...                     ...
# 1465  36.0        No      Travel_Rarely  Research & Development
# 1466  39.0        No      Travel_Rarely  Research & Development
# 1467  27.0        No      Travel_Rarely  Research & Development
# 1468  49.0        No  Travel_Frequently                   Sales
# 1469  34.0        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome EducationField  EmployeeNumber  \
# 0                    1  Life Sciences               1
# 1                    8  Life Sciences               2
# ...

# %%
sns.countplot(y=Life_science["JobRole"],hue=df["Attrition"],data=Life_science)
# Out:
# <Axes: xlabel='count', ylabel='JobRole'>

# %%
# Task 5
sales=df[df["Department"]=="Sales"]
sales
# Out:
#        Age Attrition     BusinessTravel Department  DistanceFromHome  \
# 0     41.0       Yes      Travel_Rarely      Sales                 1
# 18    53.0        No      Travel_Rarely      Sales                 2
# 21    36.0       Yes      Travel_Rarely      Sales                 9
# 27    42.0        No      Travel_Rarely      Sales                 8
# 29    46.0        No      Travel_Rarely      Sales                 2
# ...    ...       ...                ...        ...               ...
# 1454  45.0        No      Travel_Rarely      Sales                20
# 1461  50.0       Yes      Travel_Rarely      Sales                28
# 1462  39.0        No      Travel_Rarely      Sales                24
# 1464  26.0        No      Travel_Rarely      Sales                 5
# 1468  49.0        No  Travel_Frequently      Sales                 2
#
#      EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# ...

# %%
sns.countplot(x=sales["Gender"],hue=sales["Attrition"],data=sales)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>
