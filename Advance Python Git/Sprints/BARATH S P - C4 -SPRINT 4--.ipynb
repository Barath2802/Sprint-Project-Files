# %%
import pandas as pd
import numpy as np

# %%
# To read the excel
test=pd.read_csv('DS1_C4_S4_Test_Scores_Data_Practice.csv')
test
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 4     ANKYI          Urban  Non-public       6OL        Standard      74LOE
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard      T8LSK
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
#       gender            tuitionfee_waiver  test1  test2
# ...

# %%
test.isnull().sum()
# Out:
# school                0
# school_setting        0
# school_type           0
# classroom             0
# teaching_method       0
# student_id            0
# gender               10
# tuitionfee_waiver     0
# test1                 4
# test2                 4
# dtype: int64

# %%
test['gender'].value_counts()
# Out:
# gender
# Male      1071
# Female    1052
# Name: count, dtype: int64

# %%
#  to fill with the male 
test['gender']=test['gender'].fillna('Male')

# %%
test.isnull().sum()
# Out:
# school               0
# school_setting       0
# school_type          0
# classroom            0
# teaching_method      0
# student_id           0
# gender               0
# tuitionfee_waiver    0
# test1                4
# test2                4
# dtype: int64

# %%
#  to fill with the average value
test['test1']=test['test1'].fillna(test['test1'].mean())

# %%
test
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 4     ANKYI          Urban  Non-public       6OL        Standard      74LOE
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard      T8LSK
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
#       gender            tuitionfee_waiver  test1  test2
# ...

# %%
test.isnull().sum()
# Out:
# school               0
# school_setting       0
# school_type          0
# classroom            0
# teaching_method      0
# student_id           0
# gender               0
# tuitionfee_waiver    0
# test1                0
# test2                4
# dtype: int64

# %%
# to fill with the median value
test['test2']=test['test2'].fillna(test['test2'].median())

# %%
test
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 4     ANKYI          Urban  Non-public       6OL        Standard      74LOE
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard      T8LSK
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
#       gender            tuitionfee_waiver  test1  test2
# ...

# %%
test.isnull().sum()
# Out:
# school               0
# school_setting       0
# school_type          0
# classroom            0
# teaching_method      0
# student_id           0
# gender               0
# tuitionfee_waiver    0
# test1                0
# test2                0
# dtype: int64

# %%
# Task 2
test[test.duplicated(keep='first')]
# Out:
# Empty DataFrame
# Columns: [school, school_setting, school_type, classroom, teaching_method, student_id, gender, tuitionfee_waiver, test1, test2]
# Index: []

# %%
# Task 3
test['tuitionfee_waiver'] = test['tuitionfee_waiver'].replace({
    'Does not qualify': 'No',
    'Qualifies for reduced/free': 'Yes'
})
test
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 4     ANKYI          Urban  Non-public       6OL        Standard      74LOE
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard      T8LSK
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
#       gender            tuitionfee_waiver  test1  test2
# ...

# %%
# Task 4
test.groupby(['school'])['test1'].mean().reset_index()
# Out:
#    school      test1
# 0   ANKYI  61.341463
# 1   CCAAW  64.623853
# 2   CIMBB  65.067568
# 3   CUQAM  53.925234
# 4   DNQDD  54.327869
# 5   FBUMG  62.891304
# 6   GJJHK  53.194915
# 7   GOKXL  50.796875
# 8   GOOBU  38.354190
# 9   IDGFP  75.202128
# 10  KFZMY  41.865385
# 11  KZKKE  37.261261
# 12  LAYPA  62.035088
# 13  OJOBU  56.197531
# 14  QOQTS  52.543369
# 15  UAGPU  62.390805
# 16  UKPGS  78.453125
# 17  UUUQX  67.106690
# 18  VHDHF  52.666667
# 19  VKWQH  52.060000
# 20  VVTVA  36.122473
# 21  ZMNYA  68.130435
# 22  ZOWMK  41.572650

# %%
# Task 5
T=pd.pivot_table(test,index=['school'],values=['test2'],aggfunc='max').head()
T
# Out:
#         test2
# school
# ANKYI    79.0
# CCAAW    91.0
# CIMBB    88.0
# CUQAM    76.0
# DNQDD    79.0

# %%
# Task 6
df1=test[(test.school=='FBUMG')&(test.classroom=='5LQ')&(test.test2>=80)]
df1
# Out:
#     school school_setting school_type classroom teaching_method student_id  \
# 467  FBUMG          Rural  Non-public       5LQ    Experimental      04DG5
# 468  FBUMG          Rural  Non-public       5LQ    Experimental      20M2D
# 469  FBUMG          Rural  Non-public       5LQ    Experimental      39KCW
# 470  FBUMG          Rural  Non-public       5LQ    Experimental      5Z1B6
# 471  FBUMG          Rural  Non-public       5LQ    Experimental      6TLU8
# 472  FBUMG          Rural  Non-public       5LQ    Experimental      ATQQJ
# 474  FBUMG          Rural  Non-public       5LQ    Experimental      B9FSU
# 475  FBUMG          Rural  Non-public       5LQ    Experimental      EV13K
# 476  FBUMG          Rural  Non-public       5LQ    Experimental      I5H37
# 477  FBUMG          Rural  Non-public       5LQ    Experimental      JC5I9
# 478  FBUMG          Rural  Non-public       5LQ    Experimental      JPE2J
# ...

# %%
# Task 7
pd.crosstab(test['school_setting'],test['teaching_method'])
# Out:
# teaching_method  Experimental  Standard
# school_setting
# Rural                     201       309
# Suburban                  284       433
# Urban                     275       631

# %%
# Task 8
test.groupby(by=['school_setting','gender'])['gender'].count()
# Out:
# school_setting  gender
# Rural           Female    228
#                 Male      282
# Suburban        Female    368
#                 Male      349
# Urban           Female    456
#                 Male      450
# Name: gender, dtype: int64

# %%
# Task 9
test.groupby(by=['school_setting', 'gender'])['test2'].mean()
# Out:
# school_setting  gender
# Rural           Female    63.991228
#                 Male      64.092199
# Suburban        Female    76.027174
#                 Male      75.991404
# Urban           Female    61.179825
#                 Male      62.424444
# Name: test2, dtype: float64
